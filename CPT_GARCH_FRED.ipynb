# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragr81/research/blob/master/CPT_GARCH_FRED" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
